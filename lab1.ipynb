# %%
import sqlite3
import pandas as pd
from db_setup import setup_database
setup_database()
conn=sqlite3.connect('bookcycle.db')
query = """SELECT * FROM books LIMIT 5;"""
results_df = pd.read_sql(query, conn)
display(results_df)
# Out:
#                                   title            author           isbn  \
# book_id
# B1001                 A Christmas Carol   Charles Dickens  9780141324524
# B1002                A Farewell to Arms  Ernest Hemingway  9780684801469
# B1003              A Tale of Two Cities   Charles Dickens  9780141439600
# B1004    Adventures of Huckleberry Finn        Mark Twain  9780142437179
# B1005                        Agnes Grey       Anne Bronte  9780140432107
#
#                    genre  condition  purchase_price  list_price date_acquired  \
# book_id
# B1001    Classic Fiction       Good             5.5        8.99    2023-01-15
# B1002    Classic Fiction  Very Good             7.0       11.99    2023-01-15
# B1003    Classic Fiction       Fair             4.5        7.99    2023-01-16
# B1004    Classic Fiction       Good             6.0        9.99    2023-01-16
# B1005    Classic Fiction       Fair             4.0        7.99    2023-01-17
#
#         current_location  quantity
# book_id
# B1001           Suburban         2
# B1002         University         3
# B1003           Downtown         2
# B1004         University         4
# B1005           Suburban         1
