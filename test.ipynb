# %%
# %load_ext sql
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# %sql mysql+pymysql://root:dhwani2336@localhost/research_db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT * FROM author;
# Out:
#  * mysql+pymysql://root:***@localhost/research_db
#    sqlite:///Research_db_project.sql
# 20 rows affected.
# [(1, 'John Doe', 'USA'),
#  (2, 'Alice Smith', 'UK'),
#  (3, 'Rahul Mehta', 'India'),
#  (4, 'Priya Shah', 'India'),
#  (5, 'David Lee', 'Canada'),
#  (6, 'Emma Brown', 'UK'),
#  (7, 'Michael Chen', 'China'),
#  (8, 'Sophia Wilson', 'USA'),
#  (9, 'Arjun Patel', 'India'),
#  (10, 'Olivia Taylor', 'Australia'),
#  (11, 'Daniel Kim', 'South Korea'),
#  (12, 'Lucas Martin', 'France'),
#  (13, 'Isabella Garcia', 'Spain'),
#  (14, 'Ethan Clark', 'USA'),
#  (15, 'Mia Anderson', 'USA'),
#  (16, 'Noah Thomas', 'UK'),
#  (17, 'Ava Martinez', 'Mexico'),
#  (18, 'Liam White', 'Canada'),
#  (19, 'Charlotte Hall', 'UK'),
#  (20, 'James Young', 'USA')]
